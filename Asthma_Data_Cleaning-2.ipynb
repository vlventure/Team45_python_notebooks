# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
! pip install -r requirements.txt
# Out:
# ...
#   Using cached matplotlib-3.4.2-cp38-cp38-manylinux1_x86_64.whl (10.3 MB)
# ...
#   Using cached seaborn-0.11.1-py3-none-any.whl (285 kB)
# ...
#   Using cached cycler-0.10.0-py2.py3-none-any.whl (6.5 kB)
# ...
#   Using cached Pillow-8.2.0-cp38-cp38-manylinux1_x86_64.whl (3.0 MB)
# ...
#   Using cached kiwisolver-1.3.1-cp38-cp38-manylinux1_x86_64.whl (1.2 MB)
# ...
#   Using cached scipy-1.6.3-cp38-cp38-manylinux1_x86_64.whl (27.2 MB)
# ...

# %%
asthma_H_df=pd.read_csv('H_prevelance_Adults with Asthma in the Past 12 Months.csv')

# %%
asthma_H_df.head(50)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0               Topic: Health Behavior and Population          NaN
# 1                                    Subtopic: Asthma          NaN
# 2   Indicator Name: Adults with Asthma in the Past...          NaN
# 3   Indicator Description: <p>Asthma is a common d...          NaN
# 4   Notes: **Estimate is suppressed due to insuffi...          NaN
# 5                                                 NaN          NaN
# 6                                                Year  GeoTypeName
# 7                                                2003     Citywide
# 8                                                2004     Citywide
# 9                                                2006     Citywide
# 10                                               2007     Citywide
# 11                                               2008     Citywide
# 12                                               2009     Citywide
# ...

# %%
asthma_H_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Adults with Asthma in the Past 12 Months : Summarize', 'Unnamed: 6',
#        'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Unnamed: 11'],
#       dtype='object')

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_H_df = asthma_H_df.drop([0,1,2,3,4,5])

# %%
asthma_H_df.head(50)
# Out:
#    Unnamed: 0   Unnamed: 1     Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 6        Year  GeoTypeName        Borough       Geography  Geography ID
# 7        2003     Citywide  New York City   New York City             1
# 8        2004     Citywide  New York City   New York City             1
# 9        2006     Citywide  New York City   New York City             1
# 10       2007     Citywide  New York City   New York City             1
# 11       2008     Citywide  New York City   New York City             1
# 12       2009     Citywide  New York City   New York City             1
# 13       2010     Citywide  New York City   New York City             1
# 14       2011     Citywide  New York City   New York City             1
# 15       2012     Citywide  New York City   New York City             1
# 16       2013     Citywide  New York City   New York City             1
# 17       2014     Citywide  New York City   New York City             1
# ...

# %%
#show that columns 9-11 don't have numerical values
asthma_H_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                            Notes Age-Adjusted Percent
# 7                                                   NaN
# 79    *Estimate is based on small numbers so should ...
# 95    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_H_df["Unnamed: 10"].drop_duplicates()
# Out:
# 6                                          Notes Number
# 7                                                   NaN
# 79    *Estimate is based on small numbers so should ...
# 95    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_H_df["Unnamed: 11"].drop_duplicates()
# Out:
# 6                                         Notes Percent
# 7                                                   NaN
# 79    *Estimate is based on small numbers so should ...
# 95    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_H_df = asthma_H_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
asthma_H_df.head()
# Out:
#    Unnamed: 0   Unnamed: 1     Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 6        Year  GeoTypeName        Borough       Geography  Geography ID
# 7        2003     Citywide  New York City   New York City             1
# 8        2004     Citywide  New York City   New York City             1
# 9        2006     Citywide  New York City   New York City             1
# 10       2007     Citywide  New York City   New York City             1
#
#    Adults with Asthma in the Past 12 Months : Summarize            Unnamed: 6  \
# 6                                      Indicator Name    Age-Adjusted Percent
# 7            Adults with Asthma in the Past 12 Months                     4.6
# 8            Adults with Asthma in the Past 12 Months                     4.9
# 9            Adults with Asthma in the Past 12 Months                     5.3
# 10           Adults with Asthma in the Past 12 Months                     4.4
#
#    Unnamed: 7 Unnamed: 8
# 6      Number    Percent
# ...

# %%
#rename columns
asthma_H_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','adults_12mo_asthma_age_adjusted_percent','adults_12mo_asthma_number','adults_12mo_asthma_percent']

# %%
asthma_H_df = asthma_H_df.drop(columns = ['indicator_name'])

# %%
asthma_H_df.head()
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 6   Year   GeoTypeName        Borough       Geography  Geography ID
# 7   2003      Citywide  New York City   New York City             1
# 8   2004      Citywide  New York City   New York City             1
# 9   2006      Citywide  New York City   New York City             1
# 10  2007      Citywide  New York City   New York City             1
#
#    adults_12mo_asthma_age_adjusted_percent adults_12mo_asthma_number  \
# 6                     Age-Adjusted Percent                    Number
# 7                                      4.6                   244,000
# 8                                      4.9                   297,000
# 9                                      5.3                   318,000
# 10                                     4.4                   266,000
#
#    adults_12mo_asthma_percent
# 6                     Percent
# 7                         4.6
# 8                         4.9
# ...

# %%
#remove duplicate labels
asthma_H_df = asthma_H_df.drop([6])

# %%
asthma_H_df.head()
# Out:
#     year geo_type_name        borough       geography geography_id  \
# 7   2003      Citywide  New York City   New York City            1
# 8   2004      Citywide  New York City   New York City            1
# 9   2006      Citywide  New York City   New York City            1
# 10  2007      Citywide  New York City   New York City            1
# 11  2008      Citywide  New York City   New York City            1
#
#    adults_12mo_asthma_age_adjusted_percent adults_12mo_asthma_number  \
# 7                                      4.6                   244,000
# 8                                      4.9                   297,000
# 9                                      5.3                   318,000
# 10                                     4.4                   266,000
# 11                                     5.3                   322,000
#
#    adults_12mo_asthma_percent
# 7                         4.6
# 8                         4.9
# 9                         5.3
# ...

# %%
asthma_H_df=asthma_H_df.reset_index(drop=True)

# %%
asthma_H_df.head()
# Out:
#    year geo_type_name        borough       geography geography_id  \
# 0  2003      Citywide  New York City   New York City            1
# 1  2004      Citywide  New York City   New York City            1
# 2  2006      Citywide  New York City   New York City            1
# 3  2007      Citywide  New York City   New York City            1
# 4  2008      Citywide  New York City   New York City            1
#
#   adults_12mo_asthma_age_adjusted_percent adults_12mo_asthma_number  \
# 0                                     4.6                   244,000
# 1                                     4.9                   297,000
# 2                                     5.3                   318,000
# 3                                     4.4                   266,000
# 4                                     5.3                   322,000
#
#   adults_12mo_asthma_percent
# 0                        4.6
# 1                        4.9
# 2                        5.3
# 3                        4.4
# ...

# %%
#viewing the last few rows to see if there is any more descriptions to remove
asthma_H_df.tail(50)
# Out:
#                                                   year  \
# 479                                               2016
# 480                                               2017
# 481                                               2003
# 482                                               2004
# 483                                               2006
# 484                                               2007
# 485                                               2008
# 486                                               2009
# 487                                               2010
# 488                                               2011
# 489                                               2012
# 490                                               2013
# 491                                               2014
# 492                                               2016
# 493                                               2017
# 494                                               2003
# ...

# %%
#remove rows 520-528 because they have no contribution to dataset
asthma_H_df = asthma_H_df.drop([520,521,522,523,524,525,526,527,528])

# %%
asthma_H_df.tail(15)
# Out:
#      year          geo_type_name   borough                 geography  \
# 505  2016  Neighborhood (UHF 34)    Queens               West Queens
# 506  2017  Neighborhood (UHF 34)    Queens               West Queens
# 507  2003  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 508  2004  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 509  2006  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 510  2007  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 511  2008  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 512  2009  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 513  2010  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 514  2011  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 515  2012  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 516  2013  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# 517  2014  Neighborhood (UHF 34)  Brooklyn   Williamsburg - Bushwick
# ...

# %%
asthma_H_df["geo_type_name"]=  asthma_H_df["geo_type_name"].str.lower() 
asthma_H_df["borough"]=  asthma_H_df["borough"].str.lower() 
asthma_H_df["geography"]=  asthma_H_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_H_df = asthma_H_df.replace(',','', regex=True)

# %%
asthma_H_df.dtypes
# Out:
# year                                       object
# geo_type_name                              object
# borough                                    object
# geography                                  object
# geography_id                               object
# adults_12mo_asthma_age_adjusted_percent    object
# adults_12mo_asthma_number                  object
# adults_12mo_asthma_percent                 object
# dtype: object

# %%
#changing to correct datatype
asthma_H_df.year = asthma_H_df.year.astype('category')
asthma_H_df.geo_type_name = asthma_H_df.geo_type_name.astype('category')
asthma_H_df.borough = asthma_H_df.borough.astype('category')
asthma_H_df.geography = asthma_H_df.geography.astype('category')
asthma_H_df.geography_id = asthma_H_df.geography_id.astype('category')

asthma_H_df.adults_12mo_asthma_age_adjusted_percent = asthma_H_df.adults_12mo_asthma_age_adjusted_percent.astype('float')
asthma_H_df.adults_12mo_asthma_number = asthma_H_df.adults_12mo_asthma_number.astype('float')
asthma_H_df.adults_12mo_asthma_percent = asthma_H_df.adults_12mo_asthma_percent.astype('float')

# %%
asthma_H_df.dtypes
# Out:
# year                                       category
# geo_type_name                              category
# borough                                    category
# geography                                  category
# geography_id                               category
# adults_12mo_asthma_age_adjusted_percent     float64
# adults_12mo_asthma_number                   float64
# adults_12mo_asthma_percent                  float64
# dtype: object

# %%
#export clean dataset
asthma_H_df.to_csv("H_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_H_df['year'].value_counts()
# Out:
# 2003    40
# 2004    40
# 2006    40
# 2007    40
# 2008    40
# 2009    40
# 2010    40
# 2011    40
# 2012    40
# 2013    40
# 2014    40
# 2016    40
# 2017    40
# Name: year, dtype: int64

# %%
asthma_H_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 34)    442
# borough                   65
# citywide                  13
# Name: geo_type_name, dtype: int64

# %%
asthma_G_df=pd.read_csv('G_prevelenace_ Public School Children (5-14 Yrs Old) with Asthma.csv')

# %%
asthma_G_df.head(50)
# Out:
#                                            Unnamed: 0             Unnamed: 1  \
# 0               Topic: Health Behavior and Population                    NaN
# 1                                    Subtopic: Asthma                    NaN
# 2   Indicator Name: Public School Children (5-14 Y...                    NaN
# 3   Indicator Description: Asthma is a common dise...                    NaN
# 4                                                 NaN                    NaN
# 5                                                Year            GeoTypeName
# 6                                           2010-2011               Citywide
# 7                                           2011-2012               Citywide
# 8                                           2012-2013               Citywide
# 9                                           2013-2014               Citywide
# 10                                          2010-2011                Borough
# ...

# %%
asthma_G_df.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Public School Children (5-14 Yrs Old) with Asthma : Summarize',
#        'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'],
#       dtype='object')

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_G_df = asthma_G_df.drop([0,1,2,3,4])

# %%
#show that columns 8-10 don't have numerical values
asthma_G_df["Unnamed: 8"].drop_duplicates()
# Out:
# 5    Notes Estimated Annual Rate
# 6                            NaN
# Name: Unnamed: 8, dtype: object

# %%
#show that columns 8-10 don't have numerical values
asthma_G_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Number
# 6             NaN
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 8-10 don't have numerical values
asthma_G_df["Unnamed: 10"].drop_duplicates()
# Out:
# 5   NaN
# Name: Unnamed: 10, dtype: float64

# %%
#remove columns 8-10 because its a notes section with NA values
asthma_G_df = asthma_G_df.drop(columns = ['Unnamed: 8','Unnamed: 9','Unnamed: 10'])

# %%
asthma_G_df.head(10)
# Out:
#    Unnamed: 0   Unnamed: 1     Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 5        Year  GeoTypeName        Borough       Geography  Geography ID
# 6   2010-2011     Citywide  New York City   New York City             1
# 7   2011-2012     Citywide  New York City   New York City             1
# 8   2012-2013     Citywide  New York City   New York City             1
# 9   2013-2014     Citywide  New York City   New York City             1
# 10  2010-2011      Borough          Bronx           Bronx             1
# 11  2011-2012      Borough          Bronx           Bronx             1
# 12  2012-2013      Borough          Bronx           Bronx             1
# 13  2013-2014      Borough          Bronx           Bronx             1
# 14  2010-2011      Borough       Brooklyn        Brooklyn             2
#
#    Public School Children (5-14 Yrs Old) with Asthma : Summarize  \
# 5                                      Indicator Name
# ...

# %%
#rename columns
asthma_G_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','children_5_14_estimated_annual_rate_per_1000','children_5_14_number']

# %%
#remove duplicate labels
asthma_G_df = asthma_G_df.drop([5])

# %%
asthma_G_df = asthma_G_df.drop(columns = ['indicator_name'])

# %%
asthma_G_df=asthma_G_df.reset_index(drop=True)

# %%
asthma_G_df.tail(20)
# Out:
#                                                   year  \
# 180                                          2010-2011
# 181                                          2011-2012
# 182                                          2012-2013
# 183                                          2013-2014
# 184                                          2010-2011
# 185                                          2011-2012
# 186                                          2012-2013
# 187                                          2013-2014
# 188                                          2010-2011
# 189                                          2011-2012
# 190                                          2012-2013
# 191                                          2013-2014
# 192                                                NaN
# 193  Name:Public School Children (5-14 Yrs Old) wit...
# 194  Name:Public School Children (5-14 Yrs Old) wit...
# 195                                                NaN
# ...

# %%
#remove rows 192-199 because they have no contribution to dataset
asthma_G_df = asthma_G_df.drop([193,194,195,196,197,198,199,192])

# %%
asthma_G_df.tail(10)
# Out:
#           year          geo_type_name        borough  \
# 182  2012-2013  Neighborhood (UHF 42)         Queens
# 183  2013-2014  Neighborhood (UHF 42)         Queens
# 184  2010-2011  Neighborhood (UHF 42)       Brooklyn
# 185  2011-2012  Neighborhood (UHF 42)       Brooklyn
# 186  2012-2013  Neighborhood (UHF 42)       Brooklyn
# 187  2013-2014  Neighborhood (UHF 42)       Brooklyn
# 188  2010-2011  Neighborhood (UHF 42)  Staten Island
# 189  2011-2012  Neighborhood (UHF 42)  Staten Island
# 190  2012-2013  Neighborhood (UHF 42)  Staten Island
# 191  2013-2014  Neighborhood (UHF 42)  Staten Island
#
#                     geography geography_id  \
# 182               West Queens          402
# 183               West Queens          402
# 184   Williamsburg - Bushwick          211
# 185   Williamsburg - Bushwick          211
# 186   Williamsburg - Bushwick          211
# 187   Williamsburg - Bushwick          211
# 188               Willowbrook          503
# ...

# %%
asthma_G_df["geo_type_name"]=  asthma_G_df["geo_type_name"].str.lower() 
asthma_G_df["borough"]=  asthma_G_df["borough"].str.lower() 
asthma_G_df["geography"]=  asthma_G_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_G_df = asthma_G_df.replace(',','', regex=True)

# %%
asthma_G_df.head(10)
# Out:
#         year geo_type_name        borough       geography geography_id  \
# 0  2010-2011      citywide  new york city   new york city            1
# 1  2011-2012      citywide  new york city   new york city            1
# 2  2012-2013      citywide  new york city   new york city            1
# 3  2013-2014      citywide  new york city   new york city            1
# 4  2010-2011       borough          bronx           bronx            1
# 5  2011-2012       borough          bronx           bronx            1
# 6  2012-2013       borough          bronx           bronx            1
# 7  2013-2014       borough          bronx           bronx            1
# 8  2010-2011       borough       brooklyn        brooklyn            2
# 9  2011-2012       borough       brooklyn        brooklyn            2
#
#   children_5_14_estimated_annual_rate_per_1000 children_5_14_number
# 0                                         56.8                53715
# ...

# %%
asthma_G_df.dtypes
# Out:
# year                                            object
# geo_type_name                                   object
# borough                                         object
# geography                                       object
# geography_id                                    object
# children_5_14_estimated_annual_rate_per_1000    object
# children_5_14_number                            object
# dtype: object

# %%
#changing to correct datatype
asthma_G_df.year = asthma_G_df.year.astype('category')
asthma_G_df.geo_type_name = asthma_G_df.geo_type_name.astype('category')
asthma_G_df.borough = asthma_G_df.borough.astype('category')
asthma_G_df.geography = asthma_G_df.geography.astype('category')
asthma_G_df.geography_id = asthma_G_df.geography_id.astype('category')
asthma_G_df.children_5_14_estimated_annual_rate_per_1000 = asthma_G_df.children_5_14_estimated_annual_rate_per_1000.astype('float')
asthma_G_df.children_5_14_number = asthma_G_df.children_5_14_number.astype('float')

# %%
asthma_G_df.head(10)
# Out:
#         year geo_type_name        borough       geography geography_id  \
# 0  2010-2011      citywide  new york city   new york city            1
# 1  2011-2012      citywide  new york city   new york city            1
# 2  2012-2013      citywide  new york city   new york city            1
# 3  2013-2014      citywide  new york city   new york city            1
# 4  2010-2011       borough          bronx           bronx            1
# 5  2011-2012       borough          bronx           bronx            1
# 6  2012-2013       borough          bronx           bronx            1
# 7  2013-2014       borough          bronx           bronx            1
# 8  2010-2011       borough       brooklyn        brooklyn            2
# 9  2011-2012       borough       brooklyn        brooklyn            2
#
#    children_5_14_estimated_annual_rate_per_1000  children_5_14_number
# 0                                          56.8               53715.0
# ...

# %%
#export clean dataset
asthma_G_df.to_csv("G_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_G_df['year'].value_counts()
# Out:
# 2010-2011    48
# 2011-2012    48
# 2012-2013    48
# 2013-2014    48
# Name: year, dtype: int64

# %%
asthma_G_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    168
# borough                   20
# citywide                   4
# Name: geo_type_name, dtype: int64

# %%
#dataset_J and K is not grouped by UFH location, only by borough. probably not useful so skipping for now

# %%
asthma_I_df=pd.read_csv('I_prevelance_Public School Children (5-14 Yrs Old) with Persistent Asthma-2.csv')

# %%
asthma_I_df.head(20)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0               Topic: Health Behavior and Population          NaN
# 1                                    Subtopic: Asthma          NaN
# 2   Indicator Name: Public School Children (5-14 Y...          NaN
# 3                             Indicator Description:           NaN
# 4                                                 NaN          NaN
# 5                                                Year  GeoTypeName
# 6                                           2010-2011     Citywide
# 7                                           2011-2012     Citywide
# 8                                           2012-2013     Citywide
# 9                                           2013-2014     Citywide
# 10                                          2010-2011      Borough
# 11                                          2011-2012      Borough
# 12                                          2012-2013      Borough
# ...

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_I_df = asthma_I_df.drop([0,1,2,3,4])

# %%
#show that columns 8-9 don't have numerical values
asthma_I_df["Unnamed: 8"].drop_duplicates()
# Out:
# 5    Notes Estimated Annual Rate
# 6                            NaN
# Name: Unnamed: 8, dtype: object

# %%
#show that columns 8-9 don't have numerical values
asthma_I_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Number
# 6             NaN
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_I_df = asthma_I_df.drop(columns = ['Unnamed: 8','Unnamed: 9'])

# %%
#rename columns
asthma_I_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','children_5_14_persistent_estimated_annual_rate_per_1000','children_5_14_persistent_number']

# %%
asthma_I_df = asthma_I_df.drop(columns = ['indicator_name'])

# %%
asthma_I_df.head(10)
# Out:
#          year geo_type_name        borough       geography  geography_id  \
# 5        Year   GeoTypeName        Borough       Geography  Geography ID
# 6   2010-2011      Citywide  New York City   New York City             1
# 7   2011-2012      Citywide  New York City   New York City             1
# 8   2012-2013      Citywide  New York City   New York City             1
# 9   2013-2014      Citywide  New York City   New York City             1
# 10  2010-2011       Borough          Bronx           Bronx             1
# 11  2011-2012       Borough          Bronx           Bronx             1
# 12  2012-2013       Borough          Bronx           Bronx             1
# 13  2013-2014       Borough          Bronx           Bronx             1
# 14  2010-2011       Borough       Brooklyn        Brooklyn             2
#
#    children_5_14_persistent_estimated_annual_rate_per_1000  \
# 5                   Estimated Annual Rate (per 1,000)
# ...

# %%
asthma_I_df = asthma_I_df.drop([5])

# %%
asthma_I_df=asthma_I_df.reset_index(drop=True)

# %%
asthma_I_df.tail(20)
# Out:
#                                                   year  \
# 181                                          2011-2012
# 182                                          2012-2013
# 183                                          2013-2014
# 184                                          2010-2011
# 185                                          2011-2012
# 186                                          2012-2013
# 187                                          2013-2014
# 188                                          2010-2011
# 189                                          2011-2012
# 190                                          2012-2013
# 191                                          2013-2014
# 192                                                NaN
# 193  Name:Public School Children (5-14 Yrs Old) wit...
# 194                                                NaN
# 195  Name:Public School Children (5-14 Yrs Old) wit...
# 196                                                NaN
# ...

# %%
#remove rows 192-200 because they have no contribution to dataset
asthma_I_df = asthma_I_df.drop([193,194,195,196,197,198,199,192,200])

# %%
asthma_I_df["geo_type_name"]=  asthma_I_df["geo_type_name"].str.lower() 
asthma_I_df["borough"]=  asthma_I_df["borough"].str.lower() 
asthma_I_df["geography"]=  asthma_I_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_I_df = asthma_I_df.replace(',','', regex=True)

# %%
asthma_I_df.dtypes
# Out:
# year                                                       object
# geo_type_name                                              object
# borough                                                    object
# geography                                                  object
# geography_id                                               object
# children_5_14_persistent_estimated_annual_rate_per_1000    object
# children_5_14_persistent_number                            object
# dtype: object

# %%
#changing to correct datatype
asthma_I_df.year = asthma_I_df.year.astype('category')
asthma_I_df.geo_type_name = asthma_I_df.geo_type_name.astype('category')
asthma_I_df.borough = asthma_I_df.borough.astype('category')
asthma_I_df.geography = asthma_I_df.geography.astype('category')
asthma_I_df.geography_id = asthma_I_df.geography_id.astype('category')

asthma_I_df.children_5_14_persistent_estimated_annual_rate_per_1000 = asthma_I_df.children_5_14_persistent_estimated_annual_rate_per_1000.astype('float')
asthma_I_df.children_5_14_persistent_number = asthma_I_df.children_5_14_persistent_number.astype('float')

# %%
asthma_I_df.dtypes
# Out:
# year                                                       category
# geo_type_name                                              category
# borough                                                    category
# geography                                                  category
# geography_id                                               category
# children_5_14_persistent_estimated_annual_rate_per_1000     float64
# children_5_14_persistent_number                             float64
# dtype: object

# %%
#export clean dataset
asthma_I_df.to_csv("I_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_I_df['year'].value_counts()
# Out:
# 2010-2011    48
# 2011-2012    48
# 2012-2013    48
# 2013-2014    48
# Name: year, dtype: int64

# %%
asthma_I_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    168
# borough                   20
# citywide                   4
# Name: geo_type_name, dtype: int64

# %%
asthma_I_uhf42 = asthma_I_df[asthma_I_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_I_uhf42.shape
# Out:
# (168, 7)

# %%
asthma_G_uhf42 = asthma_G_df[asthma_G_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_G_uhf42.shape
# Out:
# (168, 7)

# %%
### MERGE DATASETS G, I
asthma_G_I_uhf42 = asthma_I_uhf42.merge(asthma_G_uhf42, on = ['geography_id'])
asthma_G_I_uhf42.head()
# Out:
#       year_x        geo_type_name_x borough_x             geography_x  \
# 0  2010-2011  neighborhood (uhf 42)    queens   bayside - little neck
# 1  2010-2011  neighborhood (uhf 42)    queens   bayside - little neck
# 2  2010-2011  neighborhood (uhf 42)    queens   bayside - little neck
# 3  2010-2011  neighborhood (uhf 42)    queens   bayside - little neck
# 4  2011-2012  neighborhood (uhf 42)    queens   bayside - little neck
#
#   geography_id  children_5_14_persistent_estimated_annual_rate_per_1000  \
# 0          404                                                8.7
# 1          404                                                8.7
# 2          404                                                8.7
# 3          404                                                8.7
# 4          404                                                9.0
#
#    children_5_14_persistent_number     year_y        geo_type_name_y  \
# ...

# %%
asthma_G_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_G_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_G_uhf42['borough'].value_counts()
# Out:
# brooklyn         44
# manhattan        40
# queens           40
# bronx            28
# staten island    16
# new york city     0
# Name: borough, dtype: int64

# %%
asthma_I_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_I_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_I_uhf42['borough'].value_counts()
# Out:
# brooklyn         44
# manhattan        40
# queens           40
# bronx            28
# staten island    16
# new york city     0
# Name: borough, dtype: int64

# %%
 #geography_id, geography and borough columns correspond as they should so will now also merge those columns too

### MERGE DATASETS M,O,Q by year, geo ID, geography and borough

######FOR NOW WILL NOT BE MERGING BY YEAR

asthma_G_I_uhf42 = asthma_I_uhf42.merge(asthma_G_uhf42, on = ['borough','geography_id',"geography","geo_type_name"])
asthma_G_I_uhf42.head()
# Out:
#       year_x          geo_type_name borough               geography  \
# 0  2010-2011  neighborhood (uhf 42)  queens   bayside - little neck
# 1  2010-2011  neighborhood (uhf 42)  queens   bayside - little neck
# 2  2010-2011  neighborhood (uhf 42)  queens   bayside - little neck
# 3  2010-2011  neighborhood (uhf 42)  queens   bayside - little neck
# 4  2011-2012  neighborhood (uhf 42)  queens   bayside - little neck
#
#   geography_id  children_5_14_persistent_estimated_annual_rate_per_1000  \
# 0          404                                                8.7
# 1          404                                                8.7
# 2          404                                                8.7
# 3          404                                                8.7
# 4          404                                                9.0
#
#    children_5_14_persistent_number     year_y  \
# 0                             82.0  2010-2011
# 1                             82.0  2011-2012
# ...

# %%
asthma_H_uhf34 = asthma_H_df[asthma_H_df.geo_type_name == 'neighborhood (uhf 34)']

# %%
asthma_H_uhf34['geography_id'].value_counts()
# Out:
# 301          13
# 101          13
# 303          13
# 304          13
# 305307       13
# 306308       13
# 309310       13
# 401          13
# 402          13
# 403          13
# 404406       13
# 405          13
# 407          13
# 408          13
# 409          13
# 410          13
# 501502       13
# 302          13
# 503504       13
# 203          13
# 103          13
# 210          13
# 209          13
# 208          13
# 207          13
# 206          13
# 102          13
# 205          13
# 204          13
# 211          13
# 202          13
# 201          13
# 105106107    13
# 104          13
# 5             0
# 3             0
# 2             0
# 4             0
# 1             0
# Name: geography_id, dtype: int64

# %%
asthma_M_df=pd.read_csv('M_Asthma Hospitalizations (Children 5 to 17 Yrs Old).csv')

# %%
asthma_M_df.head(20)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0               Topic: Health Behavior and Population          NaN
# 1                                    Subtopic: Asthma          NaN
# 2   Indicator Name: Asthma Hospitalizations (Child...          NaN
# 3   Indicator Description: Asthma hospitalizations...          NaN
# 4   Notes: **Estimate is suppressed due to insuffi...          NaN
# 5                                                 NaN          NaN
# 6                                                Year  GeoTypeName
# 7                                                2005     Citywide
# 8                                                2006     Citywide
# 9                                                2007     Citywide
# 10                                               2008     Citywide
# 11                                               2009     Citywide
# 12                                               2010     Citywide
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_M_df = asthma_M_df.drop([0,1,2,3,4,5])

# %%
#show that columns 8-9 don't have numerical values
asthma_M_df["Unnamed: 8"].drop_duplicates()
# Out:
# 6                            Notes Estimated Annual Rate
# 7                                                    NaN
# 85     *Estimate is based on small numbers so should ...
# 303    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 8, dtype: object

# %%
#show that columns 8-9 don't have numerical values
asthma_M_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                                          Notes Number
# 7                                                   NaN
# 85    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 8-9 because its a notes section with NA values
asthma_M_df = asthma_M_df.drop(columns = ['Unnamed: 8','Unnamed: 9'])

# %%
#rename columns
asthma_M_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','asthma_hosp_5_14_estimated_annual_rate_per_10000','asthma_hosp_5_14_number']

# %%
asthma_M_df.head(20)
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 6   Year   GeoTypeName        Borough       Geography  Geography ID
# 7   2005      Citywide  New York City   New York City             1
# 8   2006      Citywide  New York City   New York City             1
# 9   2007      Citywide  New York City   New York City             1
# 10  2008      Citywide  New York City   New York City             1
# 11  2009      Citywide  New York City   New York City             1
# 12  2010      Citywide  New York City   New York City             1
# 13  2011      Citywide  New York City   New York City             1
# 14  2012      Citywide  New York City   New York City             1
# 15  2013      Citywide  New York City   New York City             1
# 16  2014      Citywide  New York City   New York City             1
# 17  2015      Citywide  New York City   New York City             1
# 18  2016      Citywide  New York City   New York City             1
# ...

# %%
asthma_M_df = asthma_M_df.drop(columns = ['indicator_name'])

# %%
asthma_M_df = asthma_M_df.drop([6])

# %%
asthma_M_df=asthma_M_df.reset_index(drop=True)

# %%
asthma_M_df.tail(20)
# Out:
#                                                   year  \
# 570                                               2011
# 571                                               2012
# 572                                               2013
# 573                                               2014
# 574                                               2015
# 575                                               2016
# 576                                                NaN
# 577  Name:Asthma Hospitalizations (Children 5 to 17...
# 578                                      <p>&nbsp;</p>
# 579  <p>&nbsp;A hospitalization is included if it h...
# 580                                      <p>&nbsp;</p>
# 581  Name:Asthma Hospitalizations (Children 5 to 17...
# 582                                      <p>&nbsp;</p>
# 583  <p>&nbsp;A hospitalization is included if it h...
# 584                                      <p>&nbsp;</p>
# 585                                                NaN
# ...

# %%
#remove rows 576-589 because they have no contribution to dataset
asthma_M_df = asthma_M_df.drop([576,577,578,579,580,581,582,583,584,585,586,587,588,589])

# %%
asthma_M_df["geo_type_name"]=  asthma_M_df["geo_type_name"].str.lower() 
asthma_M_df["borough"]=  asthma_M_df["borough"].str.lower() 
asthma_M_df["geography"]=  asthma_M_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_M_df = asthma_M_df.replace(',','', regex=True)

# %%
asthma_M_df.dtypes
# Out:
# year                                                object
# geo_type_name                                       object
# borough                                             object
# geography                                           object
# geography_id                                        object
# asthma_hosp_5_14_estimated_annual_rate_per_10000    object
# asthma_hosp_5_14_number                             object
# dtype: object

# %%
#changing to correct datatype
asthma_M_df.year = asthma_M_df.year.astype('category')
asthma_M_df.geo_type_name = asthma_M_df.geo_type_name.astype('category')
asthma_M_df.borough = asthma_M_df.borough.astype('category')
asthma_M_df.geography = asthma_M_df.geography.astype('category')
asthma_M_df.geography_id = asthma_M_df.geography_id.astype('category')

asthma_M_df.asthma_hosp_5_14_estimated_annual_rate_per_10000 = asthma_M_df.asthma_hosp_5_14_estimated_annual_rate_per_10000.astype('float')
asthma_M_df.asthma_hosp_5_14_number = asthma_M_df.asthma_hosp_5_14_number.astype('float')

# %%
asthma_M_df.dtypes
# Out:
# year                                                category
# geo_type_name                                       category
# borough                                             category
# geography                                           category
# geography_id                                        category
# asthma_hosp_5_14_estimated_annual_rate_per_10000     float64
# asthma_hosp_5_14_number                              float64
# dtype: object

# %%
asthma_M_df.head(10)
# Out:
#    year geo_type_name        borough       geography geography_id  \
# 0  2005      citywide  new york city   new york city            1
# 1  2006      citywide  new york city   new york city            1
# 2  2007      citywide  new york city   new york city            1
# 3  2008      citywide  new york city   new york city            1
# 4  2009      citywide  new york city   new york city            1
# 5  2010      citywide  new york city   new york city            1
# 6  2011      citywide  new york city   new york city            1
# 7  2012      citywide  new york city   new york city            1
# 8  2013      citywide  new york city   new york city            1
# 9  2014      citywide  new york city   new york city            1
#
#    asthma_hosp_5_14_estimated_annual_rate_per_10000  asthma_hosp_5_14_number
# 0                                              35.9                   4656.0
# 1                                              35.4                   4525.0
# ...

# %%
#export clean dataset
asthma_M_df.to_csv("M_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_M_df['year'].value_counts()
# Out:
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2015    48
# 2016    48
# Name: year, dtype: int64

# %%
asthma_M_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    504
# borough                   60
# citywide                  12
# Name: geo_type_name, dtype: int64

# %%
asthma_M_uhf42 = asthma_M_df[asthma_M_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_M_uhf42.head()
# Out:
#     year          geo_type_name borough               geography geography_id  \
# 72  2005  neighborhood (uhf 42)  queens   bayside - little neck          404
# 73  2006  neighborhood (uhf 42)  queens   bayside - little neck          404
# 74  2007  neighborhood (uhf 42)  queens   bayside - little neck          404
# 75  2008  neighborhood (uhf 42)  queens   bayside - little neck          404
# 76  2009  neighborhood (uhf 42)  queens   bayside - little neck          404
#
#     asthma_hosp_5_14_estimated_annual_rate_per_10000  asthma_hosp_5_14_number
# 72                                              13.1                     16.0
# 73                                              14.0                     17.0
# 74                                              11.5                     14.0
# 75                                               8.1                     10.0
# 76                                              11.9                     15.0

# %%
asthma_M_uhf42.shape
# Out:
# (504, 7)

# %%
asthma_M_uhf42.isnull().values.any()
# Out:
# True

# %%
#np.where(asthma_M_uhf42.applymap(lambda x: x == ''))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
asthma_N_df=pd.read_csv('N_Asthma Hospitalizations (Children 5 to 17 Yrs Old) by NTA.csv')

# %%
asthma_N_df.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0              Topic: Health Behavior and Population          NaN
# 1                                   Subtopic: Asthma          NaN
# 2  Indicator Name: Asthma Hospitalizations (Child...          NaN
# 3                            Indicator Description:           NaN
# 4  Notes: *Estimate is based on small numbers so ...          NaN
# 5                                                NaN          NaN
# 6                                               Year  GeoTypeName
# 7                                          2014-2016     Citywide
# 8                                          2014-2016      Borough
# 9                                          2014-2016      Borough
#
#       Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_N_df = asthma_N_df.drop([0,1,2,3,4,5])

# %%
#show that columns 8-9 don't have numerical values
asthma_N_df["Unnamed: 8"].drop_duplicates()
# Out:
# 6                           Notes Average Annual Number
# 7                                                   NaN
# 14    < 4Estimate is based on small numbers so shoul...
# Name: Unnamed: 8, dtype: object

# %%
#show that columns 8-9 don't have numerical values
asthma_N_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                             Notes Average Annual Rate
# 7                                                   NaN
# 14    *Estimate is based on small numbers so should ...
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_N_df = asthma_N_df.drop(columns = ['Unnamed: 8','Unnamed: 9'])

# %%
#rename columns
asthma_N_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','asthma_hosp_5_14_nta_number', 'asthma_hosp_5_14_nta_estimated_annual_rate_per_10000']

# %%
asthma_N_df.head(10)
# Out:
#          year       geo_type_name        borough  \
# 6        Year         GeoTypeName        Borough
# 7   2014-2016            Citywide  New York City
# 8   2014-2016             Borough          Bronx
# 9   2014-2016             Borough       Brooklyn
# 10  2014-2016             Borough      Manhattan
# 11  2014-2016             Borough         Queens
# 12  2014-2016             Borough  Staten Island
# 13  2014-2016  Neighborhood (NTA)          Bronx
# 14  2014-2016  Neighborhood (NTA)  Staten Island
# 15  2014-2016  Neighborhood (NTA)  Staten Island
#
#                                       geography  geography_id  \
# 6                                     Geography  Geography ID
# 7                                 New York City             1
# 8                                         Bronx             1
# 9                                      Brooklyn             2
# 10                                    Manhattan             3
# ...

# %%
asthma_N_df = asthma_N_df.drop(columns = ['indicator_name'])

# %%
asthma_N_df = asthma_N_df.drop([6])

# %%
asthma_N_df=asthma_N_df.reset_index(drop=True)

# %%
asthma_N_df.tail(20)
# Out:
#                                                   year  \
# 188                                          2014-2016
# 189                                          2014-2016
# 190                                          2014-2016
# 191                                          2014-2016
# 192                                          2014-2016
# 193                                          2014-2016
# 194                                                NaN
# 195  Name:Asthma Hospitalizations (Children 5 to 17...
# 196                                      <p>&nbsp;</p>
# 197  <p>&nbsp;A hospitalization is included if it h...
# 198                                      <p>&nbsp;</p>
# 199  Name:Asthma Hospitalizations (Children 5 to 17...
# 200                                      <p>&nbsp;</p>
# 201  <p>&nbsp;A hospitalization is included if it h...
# 202                                      <p>&nbsp;</p>
# 203                                                NaN
# ...

# %%
#remove rows 194-207 because they have no contribution to dataset
asthma_N_df = asthma_N_df.drop([194,195,196,197,198,199,200,201,202,203,204,205,206,207])

# %%
asthma_N_df["geo_type_name"]=  asthma_N_df["geo_type_name"].str.lower() 
asthma_N_df["borough"]=  asthma_N_df["borough"].str.lower() 
asthma_N_df["geography"]=  asthma_N_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_N_df = asthma_N_df.replace(',','', regex=True)

# %%
asthma_N_df.dtypes
# Out:
# year                                                    object
# geo_type_name                                           object
# borough                                                 object
# geography                                               object
# geography_id                                            object
# asthma_hosp_5_14_nta_number                             object
# asthma_hosp_5_14_nta_estimated_annual_rate_per_10000    object
# dtype: object

# %%
#changing to correct datatype
asthma_N_df.year = asthma_N_df.year.astype('category')
asthma_N_df.geo_type_name = asthma_N_df.geo_type_name.astype('category')
asthma_N_df.borough = asthma_N_df.borough.astype('category')
asthma_N_df.geography = asthma_N_df.geography.astype('category')
asthma_N_df.geography_id = asthma_N_df.geography_id.astype('category')

asthma_N_df.asthma_hosp_5_14_nta_number = asthma_N_df.asthma_hosp_5_14_nta_number.astype('float')
asthma_N_df.asthma_hosp_5_14_nta_estimated_annual_rate_per_10000 = asthma_N_df.asthma_hosp_5_14_nta_estimated_annual_rate_per_10000.astype('float')

# %%
asthma_N_df.dtypes
# Out:
# year                                                    category
# geo_type_name                                           category
# borough                                                 category
# geography                                               category
# geography_id                                            category
# asthma_hosp_5_14_nta_number                              float64
# asthma_hosp_5_14_nta_estimated_annual_rate_per_10000     float64
# dtype: object

# %%
#export clean dataset
asthma_N_df.to_csv("N_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_N_df['year'].value_counts()
# Out:
# 2014-2016    194
# Name: year, dtype: int64

# %%
asthma_N_df['geo_type_name'].value_counts()
# Out:
# neighborhood (nta)    188
# borough                 5
# citywide                1
# Name: geo_type_name, dtype: int64

# %%
asthma_O_df=pd.read_csv('O_Asthma Hospitalizations (Children 0 to 4 Yrs Old).csv')

# %%
asthma_O_df.head(20)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0               Topic: Health Behavior and Population          NaN
# 1                                    Subtopic: Asthma          NaN
# 2   Indicator Name: Asthma Hospitalizations (Child...          NaN
# 3   Indicator Description: Asthma hospitalizations...          NaN
# 4   Notes: **Estimate is suppressed due to insuffi...          NaN
# 5                                                 NaN          NaN
# 6                                                Year  GeoTypeName
# 7                                                2000     Citywide
# 8                                                2002     Citywide
# 9                                                2003     Citywide
# 10                                               2004     Citywide
# 11                                               2005     Citywide
# 12                                               2006     Citywide
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_O_df = asthma_O_df.drop([0,1,2,3,4,5])

# %%
#show that columns 8-9 don't have numerical values
asthma_O_df["Unnamed: 8"].drop_duplicates()
# Out:
# 6                            Notes Estimated Annual Rate
# 7                                                    NaN
# 106    *Estimate is based on small numbers so should ...
# 376    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 8, dtype: object

# %%
#show that columns 8-9 don't have numerical values
asthma_O_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                                           Notes Number
# 7                                                    NaN
# 106    *Estimate is based on small numbers so should ...
# 376    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_O_df = asthma_O_df.drop(columns = ['Unnamed: 8','Unnamed: 9'])

# %%
#rename columns
asthma_O_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','asthma_hosp_0_4_estimated_annual_rate_per_10000','asthma_hosp_0_4_number']

# %%
asthma_O_df.head(10)
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 6   Year   GeoTypeName        Borough       Geography  Geography ID
# 7   2000      Citywide  New York City   New York City             1
# 8   2002      Citywide  New York City   New York City             1
# 9   2003      Citywide  New York City   New York City             1
# 10  2004      Citywide  New York City   New York City             1
# 11  2005      Citywide  New York City   New York City             1
# 12  2006      Citywide  New York City   New York City             1
# 13  2007      Citywide  New York City   New York City             1
# 14  2008      Citywide  New York City   New York City             1
# 15  2009      Citywide  New York City   New York City             1
#
#                                        indicator_name  \
# 6                                      Indicator Name
# 7   Asthma Hospitalizations (Children 0 to 4 Yrs Old)
# ...

# %%
asthma_O_df = asthma_O_df.drop(columns = ['indicator_name'])

# %%
asthma_O_df = asthma_O_df.drop([6])

# %%
asthma_O_df=asthma_O_df.reset_index(drop=True)

# %%
asthma_O_df.tail(20)
# Out:
#                                                   year  \
# 720                                               2011
# 721                                               2012
# 722                                               2013
# 723                                               2014
# 724                                               2015
# 725                                               2016
# 726                                                NaN
# 727  Name:Asthma Hospitalizations (Children 0 to 4 ...
# 728                                      <p>&nbsp;</p>
# 729  <p>A hospitalization is included if it has an ...
# 730                                      <p>&nbsp;</p>
# 731  Name:Asthma Hospitalizations (Children 0 to 4 ...
# 732                                      <p>&nbsp;</p>
# 733  <p>A hospitalization is included if it has an ...
# 734                                      <p>&nbsp;</p>
# 735                                                NaN
# ...

# %%
#remove rows 726-739 because they have no contribution to dataset
asthma_O_df = asthma_O_df.drop([726,727,728,729,730,731,732,733,734,735,736,737,738,739])

# %%
asthma_O_df["geo_type_name"]=  asthma_O_df["geo_type_name"].str.lower() 
asthma_O_df["borough"]=  asthma_O_df["borough"].str.lower() 
asthma_O_df["geography"]=  asthma_O_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_O_df = asthma_O_df.replace(',','', regex=True)

# %%
asthma_O_df.dtypes
# Out:
# year                                               object
# geo_type_name                                      object
# borough                                            object
# geography                                          object
# geography_id                                       object
# asthma_hosp_0_4_estimated_annual_rate_per_10000    object
# asthma_hosp_0_4_number                             object
# dtype: object

# %%
#changing to correct datatype
asthma_O_df.year = asthma_O_df.year.astype('category')
asthma_O_df.geo_type_name = asthma_O_df.geo_type_name.astype('category')
asthma_O_df.borough = asthma_O_df.borough.astype('category')
asthma_O_df.geography = asthma_O_df.geography.astype('category')
asthma_O_df.geography_id = asthma_O_df.geography_id.astype('category')
asthma_O_df.asthma_hosp_0_4_estimated_annual_rate_per_10000 = asthma_O_df.asthma_hosp_0_4_estimated_annual_rate_per_10000.astype('float')
asthma_O_df.asthma_hosp_0_4_number = asthma_O_df.asthma_hosp_0_4_number.astype('float')

# %%
asthma_O_df.dtypes
# Out:
# year                                               category
# geo_type_name                                      category
# borough                                            category
# geography                                          category
# geography_id                                       category
# asthma_hosp_0_4_estimated_annual_rate_per_10000     float64
# asthma_hosp_0_4_number                              float64
# dtype: object

# %%
#export clean dataset
asthma_O_df.to_csv("O_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_O_df['year'].value_counts()
# Out:
# 2002    48
# 2003    48
# 2004    48
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2015    48
# 2016    48
# 2000     6
# Name: year, dtype: int64

# %%
asthma_O_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    630
# borough                   80
# citywide                  16
# Name: geo_type_name, dtype: int64

# %%
asthma_O_uhf42 = asthma_O_df[asthma_O_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_O_uhf42.shape
# Out:
# (630, 7)

# %%
asthma_O_uhf42.isnull().values.any()
# Out:
# True

# %%
asthma_P_df=pd.read_csv('P_Asthma Hospitalizations (Adults) by NTA.csv')

# %%
asthma_P_df.head(20)
# Out:
#                                            Unnamed: 0          Unnamed: 1  \
# 0               Topic: Health Behavior and Population                 NaN
# 1                                    Subtopic: Asthma                 NaN
# 2   Indicator Name: Asthma Hospitalizations (Adult...                 NaN
# 3                             Indicator Description:                  NaN
# 4                                                 NaN                 NaN
# 5                                                Year         GeoTypeName
# 6                                           2012-2014            Citywide
# 7                                           2012-2014             Borough
# 8                                           2012-2014             Borough
# 9                                           2012-2014             Borough
# 10                                          2012-2014             Borough
# 11                                          2012-2014             Borough
# ...

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_P_df = asthma_P_df.drop([0,1,2,3,4])

# %%
#show that columns 9-11 don't have numerical values
asthma_P_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Average Annual Age-Adjusted Rate
# 6                                       NaN
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_P_df["Unnamed: 10"].drop_duplicates()
# Out:
# 5    Notes Average Annual Number
# 6                            NaN
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_P_df["Unnamed: 11"].drop_duplicates()
# Out:
# 5    Notes Average Annual Rate
# 6                          NaN
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_P_df = asthma_P_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
#rename columns
asthma_P_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','asthma_hosp_adult_nta_estimated_age_adjusted_rate_per10k','asthma_hosp_adult_nta_number', 'asthma_hosp_adult_nta_estimated_rate_per10k']

# %%
asthma_P_df = asthma_P_df.drop(columns = ['indicator_name'])

# %%
asthma_P_df.head(10)
# Out:
#          year       geo_type_name        borough  \
# 5        Year         GeoTypeName        Borough
# 6   2012-2014            Citywide  New York City
# 7   2012-2014             Borough          Bronx
# 8   2012-2014             Borough       Brooklyn
# 9   2012-2014             Borough      Manhattan
# 10  2012-2014             Borough         Queens
# 11  2012-2014             Borough  Staten Island
# 12  2012-2014  Neighborhood (NTA)          Bronx
# 13  2012-2014  Neighborhood (NTA)  Staten Island
# 14  2012-2014  Neighborhood (NTA)  Staten Island
#
#                                       geography  geography_id  \
# 5                                     Geography  Geography ID
# 6                                 New York City             1
# 7                                         Bronx             1
# 8                                      Brooklyn             2
# 9                                     Manhattan             3
# ...

# %%
asthma_P_df = asthma_P_df.drop([5])

# %%
asthma_P_df=asthma_P_df.reset_index(drop=True)

# %%
asthma_P_df.tail(20)
# Out:
#                                                   year  \
# 192                                          2012-2014
# 193                                          2012-2014
# 194                                                NaN
# 195       Name:Asthma Hospitalizations (Adults) by NTA
# 196                                      <p>&nbsp;</p>
# 197  <p>An ED visit is included if it has an ICD-9 ...
# 198                                      <p>&nbsp;</p>
# 199       Name:Asthma Hospitalizations (Adults) by NTA
# 200                                      <p>&nbsp;</p>
# 201  <p>An ED visit is included if it has an ICD-9 ...
# 202                                      <p>&nbsp;</p>
# 203       Name:Asthma Hospitalizations (Adults) by NTA
# 204                                      <p>&nbsp;</p>
# 205  <p>An ED visit is included if it has an ICD-9 ...
# 206                                      <p>&nbsp;</p>
# 207                                                NaN
# ...

# %%
#remove rows 194-211 because they have no contribution to dataset
asthma_P_df = asthma_P_df.drop([194,195,196,197,198,199,200,201,202,203,204,205,206,207,208,209,210,211])

# %%
asthma_P_df["geo_type_name"]=  asthma_P_df["geo_type_name"].str.lower() 
asthma_P_df["borough"]=  asthma_P_df["borough"].str.lower() 
asthma_P_df["geography"]=  asthma_P_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_P_df = asthma_P_df.replace(',','', regex=True)

# %%
asthma_P_df.dtypes
# Out:
# year                                                        object
# geo_type_name                                               object
# borough                                                     object
# geography                                                   object
# geography_id                                                object
# asthma_hosp_adult_nta_estimated_age_adjusted_rate_per10k    object
# asthma_hosp_adult_nta_number                                object
# asthma_hosp_adult_nta_estimated_rate_per10k                 object
# dtype: object

# %%
#changing to correct datatype
asthma_P_df.year = asthma_P_df.year.astype('category')
asthma_P_df.geo_type_name = asthma_P_df.geo_type_name.astype('category')
asthma_P_df.borough = asthma_P_df.borough.astype('category')
asthma_P_df.geography = asthma_P_df.geography.astype('category')
asthma_P_df.geography_id = asthma_P_df.geography_id.astype('category')
asthma_P_df.asthma_hosp_adult_nta_estimated_age_adjusted_rate_per10k = asthma_P_df.asthma_hosp_adult_nta_estimated_age_adjusted_rate_per10k.astype('float')
asthma_P_df.asthma_hosp_adult_nta_number = asthma_P_df.asthma_hosp_adult_nta_number.astype('float')
asthma_P_df.asthma_hosp_adult_nta_estimated_rate_per10k  = asthma_P_df.asthma_hosp_adult_nta_estimated_rate_per10k.astype('float')

# %%
asthma_P_df.dtypes
# Out:
# year                                                        category
# geo_type_name                                               category
# borough                                                     category
# geography                                                   category
# geography_id                                                category
# asthma_hosp_adult_nta_estimated_age_adjusted_rate_per10k     float64
# asthma_hosp_adult_nta_number                                 float64
# asthma_hosp_adult_nta_estimated_rate_per10k                  float64
# dtype: object

# %%
#export clean dataset
asthma_P_df.to_csv("P_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_P_df['year'].value_counts()
# Out:
# 2012-2014    194
# Name: year, dtype: int64

# %%
asthma_P_df['geo_type_name'].value_counts()
# Out:
# neighborhood (nta)    188
# borough                 5
# citywide                1
# Name: geo_type_name, dtype: int64

# %%
asthma_Q_df=pd.read_csv('Q_Asthma Hospitalizations (Adults).csv')

# %%
asthma_Q_df.head(20)
# Out:
#                                            Unnamed: 0   Unnamed: 1  \
# 0               Topic: Health Behavior and Population          NaN
# 1                                    Subtopic: Asthma          NaN
# 2    Indicator Name: Asthma Hospitalizations (Adults)          NaN
# 3   Indicator Description: Asthma hospitalizations...          NaN
# 4   Notes: **Estimate is suppressed due to insuffi...          NaN
# 5                                                 NaN          NaN
# 6                                                Year  GeoTypeName
# 7                                                2005     Citywide
# 8                                                2006     Citywide
# 9                                                2007     Citywide
# 10                                               2008     Citywide
# 11                                               2009     Citywide
# 12                                               2010     Citywide
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_Q_df = asthma_Q_df.drop([0,1,2,3,4,5])

# %%
#show that columns 9-11 don't have numerical values
asthma_Q_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                                Notes Age-Adjusted Rate
# 7                                                    NaN
# 17     ‡ <strong style="color: red;">Data from 2015 a...
# 282    *Estimate is based on small numbers so should ...
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_Q_df["Unnamed: 10"].drop_duplicates()
# Out:
# 6                            Notes Estimated Annual Rate
# 7                                                    NaN
# 17     ‡ <strong style="color: red;">Data from 2015 a...
# 282    *Estimate is based on small numbers so should ...
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_Q_df["Unnamed: 11"].drop_duplicates()
# Out:
# 6                                           Notes Number
# 7                                                    NaN
# 17     ‡ <strong style="color: red;">Data from 2015 a...
# 282    **Estimate is suppressed due to insufficient d...
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_Q_df = asthma_Q_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
#rename columns
asthma_Q_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','asthma_hosp_adult_estimated__age_adjusted_rate_per10k', 'asthma_hosp_adult_estimated__rate_per10k','asthma_hosp_adult_number']

# %%
asthma_Q_df.head(10)
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 6   Year   GeoTypeName        Borough       Geography  Geography ID
# 7   2005      Citywide  New York City   New York City             1
# 8   2006      Citywide  New York City   New York City             1
# 9   2007      Citywide  New York City   New York City             1
# 10  2008      Citywide  New York City   New York City             1
# 11  2009      Citywide  New York City   New York City             1
# 12  2010      Citywide  New York City   New York City             1
# 13  2011      Citywide  New York City   New York City             1
# 14  2012      Citywide  New York City   New York City             1
# 15  2013      Citywide  New York City   New York City             1
#
#                       indicator_name  \
# 6                     Indicator Name
# 7   Asthma Hospitalizations (Adults)
# 8   Asthma Hospitalizations (Adults)
# 9   Asthma Hospitalizations (Adults)
# ...

# %%
asthma_Q_df = asthma_Q_df.drop(columns = ['indicator_name'])

# %%
asthma_Q_df = asthma_Q_df.drop([6])

# %%
asthma_Q_df=asthma_Q_df.reset_index(drop=True)

# %%
asthma_Q_df.tail(20)
# Out:
#                                                   year  \
# 527                                               2014
# 528                                               2016
# 529                                                NaN
# 530              Name:Asthma Hospitalizations (Adults)
# 531                                      <p>&nbsp;</p>
# 532  <p>A hospitalization is included if it has an ...
# 533                                      <p>&nbsp;</p>
# 534              Name:Asthma Hospitalizations (Adults)
# 535                                      <p>&nbsp;</p>
# 536  <p>A hospitalization is included if it has an ...
# 537                                      <p>&nbsp;</p>
# 538              Name:Asthma Hospitalizations (Adults)
# 539                                      <p>&nbsp;</p>
# 540  <p>A hospitalization is included if it has an ...
# 541                                      <p>&nbsp;</p>
# 542                                                NaN
# ...

# %%
#remove rows 529-546 because they have no contribution to dataset
asthma_Q_df = asthma_Q_df.drop([529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546])

# %%
asthma_Q_df["geo_type_name"]=  asthma_Q_df["geo_type_name"].str.lower() 
asthma_Q_df["borough"]=  asthma_Q_df["borough"].str.lower() 
asthma_Q_df["geography"]=  asthma_Q_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_Q_df = asthma_Q_df.replace(',','', regex=True)

# %%
asthma_Q_df.dtypes
# Out:
# year                                                     object
# geo_type_name                                            object
# borough                                                  object
# geography                                                object
# geography_id                                             object
# asthma_hosp_adult_estimated__age_adjusted_rate_per10k    object
# asthma_hosp_adult_estimated__rate_per10k                 object
# asthma_hosp_adult_number                                 object
# dtype: object

# %%
#changing to correct datatype
asthma_Q_df.year = asthma_Q_df.year.astype('category')
asthma_Q_df.geo_type_name = asthma_Q_df.geo_type_name.astype('category')
asthma_Q_df.borough = asthma_Q_df.borough.astype('category')
asthma_Q_df.geography = asthma_Q_df.geography.astype('category')
asthma_Q_df.geography_id = asthma_Q_df.geography_id.astype('category')

asthma_Q_df.asthma_hosp_adult_estimated__age_adjusted_rate_per10k = asthma_Q_df.asthma_hosp_adult_estimated__age_adjusted_rate_per10k.astype('float')
asthma_Q_df.asthma_hosp_adult_estimated__rate_per10k = asthma_Q_df.asthma_hosp_adult_estimated__rate_per10k.astype('float')
asthma_Q_df.asthma_hosp_adult_number  = asthma_Q_df.asthma_hosp_adult_number.astype('float')

# %%
asthma_Q_df.dtypes
# Out:
# year                                                     category
# geo_type_name                                            category
# borough                                                  category
# geography                                                category
# geography_id                                             category
# asthma_hosp_adult_estimated__age_adjusted_rate_per10k     float64
# asthma_hosp_adult_estimated__rate_per10k                  float64
# asthma_hosp_adult_number                                  float64
# dtype: object

# %%
#export clean dataset
asthma_Q_df.to_csv("Q_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_Q_df['year'].value_counts()
# Out:
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2016    48
# 2015     1
# Name: year, dtype: int64

# %%
asthma_Q_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    462
# borough                   55
# citywide                  12
# Name: geo_type_name, dtype: int64

# %%
asthma_Q_uhf42 = asthma_Q_df[asthma_Q_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_Q_uhf42.shape
# Out:
# (462, 8)

# %%
### MERGE DATASETS M,O,Q by year and geo ID
asthma_M_O_uhf42 = asthma_M_uhf42.merge(asthma_O_uhf42, on = ['year','geography_id'])
asthma_M_O_Q_uhf42 = asthma_M_O_uhf42.merge(asthma_Q_uhf42, on = ['year','geography_id'])
asthma_M_O_Q_uhf42.head()
# Out:
#    year        geo_type_name_x borough_x             geography_x geography_id  \
# 0  2005  neighborhood (uhf 42)    queens   bayside - little neck          404
# 1  2006  neighborhood (uhf 42)    queens   bayside - little neck          404
# 2  2007  neighborhood (uhf 42)    queens   bayside - little neck          404
# 3  2008  neighborhood (uhf 42)    queens   bayside - little neck          404
# 4  2009  neighborhood (uhf 42)    queens   bayside - little neck          404
#
#    asthma_hosp_5_14_estimated_annual_rate_per_10000  asthma_hosp_5_14_number  \
# 0                                              13.1                     16.0
# 1                                              14.0                     17.0
# 2                                              11.5                     14.0
# 3                                               8.1                     10.0
# 4                                              11.9                     15.0
#
# ...

# %%
## FURTHER CLEANING THE MERGED DATA
### do we have the same number of different values in "georgraphy" and in "geography_id" in the individual uhf42 groupings?
asthma_Q_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_Q_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_Q_uhf42['borough'].value_counts()
# Out:
# brooklyn         121
# manhattan        110
# queens           110
# bronx             77
# staten island     44
# new york city      0
# Name: borough, dtype: int64

# %%
asthma_M_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_M_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_M_uhf42['borough'].value_counts()
# Out:
# brooklyn         132
# manhattan        120
# queens           120
# bronx             84
# staten island     48
# new york city      0
# Name: borough, dtype: int64

# %%
asthma_O_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_O_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_O_uhf42['borough'].value_counts()
# Out:
# brooklyn         165
# manhattan        150
# queens           150
# bronx            105
# staten island     60
# new york city      0
# Name: borough, dtype: int64

# %%
# geography_id, geography and borough columns correspond as they should so will now also merge those columns too

### MERGE DATASETS M,O,Q by year, geo ID, geography and borough

asthma_M_O_uhf42 = asthma_M_uhf42.merge(asthma_O_uhf42, on = ['year','borough','geography_id',"geography","geo_type_name"])
asthma_M_O_Q_uhf42 = asthma_M_O_uhf42.merge(asthma_Q_uhf42, on = ['year','borough','geography_id',"geography", "geo_type_name"])
asthma_M_O_Q_uhf42.head()
# Out:
#    year          geo_type_name borough               geography geography_id  \
# 0  2005  neighborhood (uhf 42)  queens   bayside - little neck          404
# 1  2006  neighborhood (uhf 42)  queens   bayside - little neck          404
# 2  2007  neighborhood (uhf 42)  queens   bayside - little neck          404
# 3  2008  neighborhood (uhf 42)  queens   bayside - little neck          404
# 4  2009  neighborhood (uhf 42)  queens   bayside - little neck          404
#
#    asthma_hosp_5_14_estimated_annual_rate_per_10000  asthma_hosp_5_14_number  \
# 0                                              13.1                     16.0
# 1                                              14.0                     17.0
# 2                                              11.5                     14.0
# 3                                               8.1                     10.0
# 4                                              11.9                     15.0
#
# ...

# %%
asthma_M_O_Q_uhf42.dtypes
# Out:
# year                                                       object
# geo_type_name                                            category
# borough                                                  category
# geography                                                category
# geography_id                                             category
# asthma_hosp_5_14_estimated_annual_rate_per_10000          float64
# asthma_hosp_5_14_number                                   float64
# asthma_hosp_0_4_estimated_annual_rate_per_10000           float64
# asthma_hosp_0_4_number                                    float64
# asthma_hosp_adult_estimated__age_adjusted_rate_per10k     float64
# asthma_hosp_adult_estimated__rate_per10k                  float64
# asthma_hosp_adult_number                                  float64
# dtype: object

# %%
#export merged uhf42 for hospitalization data
asthma_M_O_Q_uhf42.to_csv("MERGED_asthmaMOQ_hospitalizations_uhf42.csv", encoding="utf-8")

# %%
asthma_A_df=pd.read_csv('A_Asthma Emergency Department Visits (Adults) by NTA.csv')

# %%
asthma_A_df.head(20)
# Out:
#                                            Unnamed: 0          Unnamed: 1  \
# 0               Topic: Health Behavior and Population                 NaN
# 1                                    Subtopic: Asthma                 NaN
# 2   Indicator Name: Asthma Emergency Department Vi...                 NaN
# 3                             Indicator Description:                  NaN
# 4                                                 NaN                 NaN
# 5                                                Year         GeoTypeName
# 6                                           2012-2014            Citywide
# 7                                           2012-2014             Borough
# 8                                           2012-2014             Borough
# 9                                           2012-2014             Borough
# 10                                          2012-2014             Borough
# 11                                          2012-2014             Borough
# ...

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_A_df = asthma_A_df.drop([0,1,2,3,4])

# %%
#show that columns 9-11 don't have numerical values
asthma_A_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Average Annual Age-Adjusted Rate
# 6                                       NaN
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_A_df["Unnamed: 10"].drop_duplicates()
# Out:
# 5    Notes Average Annual Number
# 6                            NaN
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_A_df["Unnamed: 11"].drop_duplicates()
# Out:
# 5    Notes Average Annual Rate
# 6                          NaN
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_A_df = asthma_A_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
#rename columns
asthma_A_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_adult_nta_estimated_age_adjusted_rate_per10k','ed_annual_adult_nta_number', 'ed_annual_adult_nta_rate_per10k']

# %%
asthma_A_df = asthma_A_df.drop(columns = ['indicator_name'])

# %%
asthma_A_df.head(10)
# Out:
#          year       geo_type_name        borough  \
# 5        Year         GeoTypeName        Borough
# 6   2012-2014            Citywide  New York City
# 7   2012-2014             Borough          Bronx
# 8   2012-2014             Borough       Brooklyn
# 9   2012-2014             Borough      Manhattan
# 10  2012-2014             Borough         Queens
# 11  2012-2014             Borough  Staten Island
# 12  2012-2014  Neighborhood (NTA)          Bronx
# 13  2017-2019  Neighborhood (NTA)          Bronx
# 14  2012-2014  Neighborhood (NTA)  Staten Island
#
#                                       geography  geography_id  \
# 5                                     Geography  Geography ID
# 6                                 New York City             1
# 7                                         Bronx             1
# 8                                      Brooklyn             2
# 9                                     Manhattan             3
# ...

# %%
asthma_A_df = asthma_A_df.drop([5])

# %%
asthma_A_df=asthma_A_df.reset_index(drop=True)

# %%
asthma_A_df.tail(30)
# Out:
#                                                   year  \
# 376                                          2012-2014
# 377                                          2017-2019
# 378                                          2012-2014
# 379                                          2017-2019
# 380                                          2012-2014
# 381                                          2017-2019
# 382                                                NaN
# 383  Name:Asthma Emergency Department Visits (Adult...
# 384                                      <p>&nbsp;</p>
# 385  <p>ED visits include both patients who are tre...
# 386                                      <p>&nbsp;</p>
# 387  <p>An ED visit is included if it has an ICD-9 ...
# 388                                      <p>&nbsp;</p>
# 389  Name:Asthma Emergency Department Visits (Adult...
# 390                                      <p>&nbsp;</p>
# 391  <p>ED visits include both patients who are tre...
# ...

# %%
#remove rows 382-405 because they have no contribution to dataset
asthma_A_df = asthma_A_df.drop([382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399,400,401,402,403,404,405])

# %%
asthma_A_df["geo_type_name"]=  asthma_A_df["geo_type_name"].str.lower() 
asthma_A_df["borough"]=  asthma_A_df["borough"].str.lower() 
asthma_A_df["geography"]=  asthma_A_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_A_df = asthma_A_df.replace(',','', regex=True)

# %%
asthma_A_df.dtypes
# Out:
# year                                                      object
# geo_type_name                                             object
# borough                                                   object
# geography                                                 object
# geography_id                                              object
# ed_annual_adult_nta_estimated_age_adjusted_rate_per10k    object
# ed_annual_adult_nta_number                                object
# ed_annual_adult_nta_rate_per10k                           object
# dtype: object

# %%
#changing to correct datatype
asthma_A_df.year = asthma_A_df.year.astype('category')
asthma_A_df.geo_type_name = asthma_A_df.geo_type_name.astype('category')
asthma_A_df.borough = asthma_A_df.borough.astype('category')
asthma_A_df.geography = asthma_A_df.geography.astype('category')
asthma_A_df.geography_id = asthma_A_df.geography_id.astype('category')

asthma_A_df.ed_annual_adult_nta_estimated_age_adjusted_rate_per10k = asthma_A_df.ed_annual_adult_nta_estimated_age_adjusted_rate_per10k.astype('float')
asthma_A_df.ed_annual_adult_nta_number = asthma_A_df.ed_annual_adult_nta_number.astype('float')
asthma_A_df.ed_annual_adult_nta_rate_per10k  = asthma_A_df.ed_annual_adult_nta_rate_per10k.astype('float')

# %%
asthma_A_df.dtypes
# Out:
# year                                                      category
# geo_type_name                                             category
# borough                                                   category
# geography                                                 category
# geography_id                                              category
# ed_annual_adult_nta_estimated_age_adjusted_rate_per10k     float64
# ed_annual_adult_nta_number                                 float64
# ed_annual_adult_nta_rate_per10k                            float64
# dtype: object

# %%
#export clean dataset
asthma_A_df.to_csv("A_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_A_df['year'].value_counts()
# Out:
# 2012-2014    194
# 2017-2019    188
# Name: year, dtype: int64

# %%
asthma_A_df['geo_type_name'].value_counts()
# Out:
# neighborhood (nta)    376
# borough                 5
# citywide                1
# Name: geo_type_name, dtype: int64

# %%
asthma_B_df=pd.read_csv('B_Asthma Emergency Department Visits (Children 0 to 4 Yrs Old) by NTA.csv')

# %%
asthma_B_df.head(20)
# Out:
#                                            Unnamed: 0          Unnamed: 1  \
# 0               Topic: Health Behavior and Population                 NaN
# 1                                    Subtopic: Asthma                 NaN
# 2   Indicator Name: Asthma Emergency Department Vi...                 NaN
# 3                             Indicator Description:                  NaN
# 4   Notes: *Estimate is based on small numbers so ...                 NaN
# 5                                                 NaN                 NaN
# 6                                                Year         GeoTypeName
# 7                                           2014-2016  Neighborhood (NTA)
# 8                                           2017-2019  Neighborhood (NTA)
# 9                                           2014-2016  Neighborhood (NTA)
# 10                                          2017-2019  Neighborhood (NTA)
# 11                                          2014-2016  Neighborhood (NTA)
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_B_df = asthma_B_df.drop([0,1,2,3,4,5])

# %%
#show that columns 9-11 don't have numerical values
asthma_B_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                            Notes Average Annual Number
# 7                                                    NaN
# 144    *Estimate is based on small numbers so should ...
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_B_df["Unnamed: 10"].drop_duplicates()
# Out:
# 6                             Notes Average Annual Rate
# 7                                                   NaN
# 91    *Estimate is based on small numbers so should ...
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_B_df["Unnamed: 11"].drop_duplicates()
# Out:
# 6                                          Notes Number
# 7                                                   NaN
# 91    *Estimate is based on small numbers so should ...
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_B_df = asthma_B_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
#rename columns
asthma_B_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_0_4_number_per10k','ed_annual_0_4_rate_per10k', 'ed_0_4_number']

# %%
asthma_B_df.head(10)
# Out:
#          year       geo_type_name        borough  \
# 6        Year         GeoTypeName        Borough
# 7   2014-2016  Neighborhood (NTA)          Bronx
# 8   2017-2019  Neighborhood (NTA)          Bronx
# 9   2014-2016  Neighborhood (NTA)  Staten Island
# 10  2017-2019  Neighborhood (NTA)  Staten Island
# 11  2014-2016  Neighborhood (NTA)  Staten Island
# 12  2017-2019  Neighborhood (NTA)  Staten Island
# 13  2014-2016  Neighborhood (NTA)         Queens
# 14  2017-2019  Neighborhood (NTA)         Queens
# 15  2014-2016  Neighborhood (NTA)         Queens
#
#                                       geography  geography_id  \
# 6                                     Geography  Geography ID
# 7                       Allerton-Pelham Gardens           531
# 8                       Allerton-Pelham Gardens           531
# 9    Annadale-Huguenot-Prince's Bay-Eltingville          8501
# 10   Annadale-Huguenot-Prince's Bay-Eltingville          8501
# ...

# %%
asthma_B_df = asthma_B_df.drop(columns = ['indicator_name'])

# %%
asthma_B_df = asthma_B_df.drop([6])

# %%
asthma_B_df=asthma_B_df.reset_index(drop=True)

# %%
asthma_B_df.tail(30)
# Out:
#                                                   year  \
# 361                                          2017-2019
# 362                                          2014-2016
# 363                                          2017-2019
# 364                                          2014-2016
# 365                                          2017-2019
# 366                                          2014-2016
# 367                                          2017-2019
# 368                                          2014-2016
# 369                                          2017-2019
# 370                                          2014-2016
# 371                                          2017-2019
# 372                                          2014-2016
# 373                                          2017-2019
# 374                                          2014-2016
# 375                                          2017-2019
# 376                                                NaN
# ...

# %%
#remove rows 376-39 because they have no contribution to dataset
asthma_B_df = asthma_B_df.drop([376,377,378,379,380,381,382,383,384,385,386,387,388,389,390])

# %%
asthma_B_df["geo_type_name"]=  asthma_B_df["geo_type_name"].str.lower() 
asthma_B_df["borough"]=  asthma_B_df["borough"].str.lower() 
asthma_B_df["geography"]=  asthma_B_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_B_df = asthma_B_df.replace(',','', regex=True)

# %%
asthma_B_df.dtypes
# Out:
# year                           object
# geo_type_name                  object
# borough                        object
# geography                      object
# geography_id                   object
# ed_annual_0_4_number_per10k    object
# ed_annual_0_4_rate_per10k      object
# ed_0_4_number                  object
# dtype: object

# %%
#changing to correct datatype
asthma_B_df.year = asthma_B_df.year.astype('category')
asthma_B_df.geo_type_name = asthma_B_df.geo_type_name.astype('category')
asthma_B_df.borough = asthma_B_df.borough.astype('category')
asthma_B_df.geography = asthma_B_df.geography.astype('category')
asthma_B_df.geography_id = asthma_B_df.geography_id.astype('category')

asthma_B_df.ed_annual_0_4_number_per10k = asthma_B_df.ed_annual_0_4_number_per10k.astype('float')
asthma_B_df.ed_annual_0_4_rate_per10k = asthma_B_df.ed_annual_0_4_rate_per10k.astype('float')
asthma_B_df.ed_0_4_number  = asthma_B_df.ed_0_4_number.astype('float')

# %%
asthma_B_df.head(10)
# Out:
#         year       geo_type_name        borough  \
# 0  2014-2016  neighborhood (nta)          bronx
# 1  2017-2019  neighborhood (nta)          bronx
# 2  2014-2016  neighborhood (nta)  staten island
# 3  2017-2019  neighborhood (nta)  staten island
# 4  2014-2016  neighborhood (nta)  staten island
# 5  2017-2019  neighborhood (nta)  staten island
# 6  2014-2016  neighborhood (nta)         queens
# 7  2017-2019  neighborhood (nta)         queens
# 8  2014-2016  neighborhood (nta)         queens
# 9  2017-2019  neighborhood (nta)         queens
#
#                                      geography geography_id  \
# 0                      allerton-pelham gardens          531
# 1                      allerton-pelham gardens          531
# 2   annadale-huguenot-prince's bay-eltingville         8501
# 3   annadale-huguenot-prince's bay-eltingville         8501
# 4                                arden heights         8548
# 5                                arden heights         8548
# ...

# %%
#export clean dataset
asthma_B_df.to_csv("B_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_B_df['year'].value_counts()
# Out:
# 2014-2016    188
# 2017-2019    188
# Name: year, dtype: int64

# %%
asthma_B_df['geo_type_name'].value_counts()
# Out:
# neighborhood (nta)    376
# Name: geo_type_name, dtype: int64

# %%
asthma_C_df=pd.read_csv('C_Asthma Emergency Department Visits (Adults).csv')

# %%
asthma_C_df.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0              Topic: Health Behavior and Population          NaN
# 1                                   Subtopic: Asthma          NaN
# 2  Indicator Name: Asthma Emergency Department Vi...          NaN
# 3  Indicator Description: Severe asthma attacks c...          NaN
# 4  Notes: ‡ <strong style="color: red;">Data from...          NaN
# 5                                                NaN          NaN
# 6                                               Year  GeoTypeName
# 7                                               2005     Citywide
# 8                                               2006     Citywide
# 9                                               2007     Citywide
#
#       Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_C_df = asthma_C_df.drop([0,1,2,3,4,5])

# %%
#show that columns 9-11 don't have numerical values
asthma_C_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                               Notes Age-Adjusted Rate
# 7                                                   NaN
# 17    ‡ <strong style="color: red;">Data from 2015 a...
# Name: Unnamed: 9, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_C_df["Unnamed: 10"].drop_duplicates()
# Out:
# 6                           Notes Estimated Annual Rate
# 7                                                   NaN
# 17    ‡ <strong style="color: red;">Data from 2015 a...
# Name: Unnamed: 10, dtype: object

# %%
#show that columns 9-11 don't have numerical values
asthma_C_df["Unnamed: 11"].drop_duplicates()
# Out:
# 6                                          Notes Number
# 7                                                   NaN
# 17    ‡ <strong style="color: red;">Data from 2015 a...
# Name: Unnamed: 11, dtype: object

# %%
#remove columns 9-11 because its a notes section with NA values
asthma_C_df = asthma_C_df.drop(columns = ['Unnamed: 9','Unnamed: 10','Unnamed: 11'])

# %%
#rename columns
asthma_C_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_adult_estimated_age_adjusted_rate_per10k', 'ed_annual_adult_rate_per10k', 'ed_annual_adult_number']

# %%
asthma_C_df.head(10)
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 6   Year   GeoTypeName        Borough       Geography  Geography ID
# 7   2005      Citywide  New York City   New York City             1
# 8   2006      Citywide  New York City   New York City             1
# 9   2007      Citywide  New York City   New York City             1
# 10  2008      Citywide  New York City   New York City             1
# 11  2009      Citywide  New York City   New York City             1
# 12  2010      Citywide  New York City   New York City             1
# 13  2011      Citywide  New York City   New York City             1
# 14  2012      Citywide  New York City   New York City             1
# 15  2013      Citywide  New York City   New York City             1
#
#                                  indicator_name  \
# 6                                Indicator Name
# 7   Asthma Emergency Department Visits (Adults)
# 8   Asthma Emergency Department Visits (Adults)
# ...

# %%
asthma_C_df = asthma_C_df.drop([6])

# %%
asthma_C_df = asthma_C_df.drop(columns = ['indicator_name'])

# %%
asthma_C_df=asthma_C_df.reset_index(drop=True)

# %%
asthma_C_df.tail(30)
# Out:
#                                                   year  \
# 523                                               2010
# 524                                               2011
# 525                                               2012
# 526                                               2013
# 527                                               2014
# 528                                               2016
# 529                                                NaN
# 530   Name:Asthma Emergency Department Visits (Adults)
# 531                                      <p>&nbsp;</p>
# 532  <p>ED visits include both patients who are tre...
# 533                                      <p>&nbsp;</p>
# 534  <p>An ED visit is included if it has an ICD-9 ...
# 535                                      <p>&nbsp;</p>
# 536   Name:Asthma Emergency Department Visits (Adults)
# 537                                      <p>&nbsp;</p>
# 538  <p>ED visits include both patients who are tre...
# ...

# %%
#remove rows 529-552 because they have no contribution to dataset
asthma_C_df = asthma_C_df.drop([529,530,531,532,533,534,535,536,537,538,539,540,541,542,543,544,545,546,547,548,549,550,551,552])

# %%
asthma_C_df["geo_type_name"]=  asthma_C_df["geo_type_name"].str.lower() 
asthma_C_df["borough"]=  asthma_C_df["borough"].str.lower() 
asthma_C_df["geography"]=  asthma_C_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_C_df = asthma_C_df.replace(',','', regex=True)

# %%
asthma_C_df.dtypes
# Out:
# year                                                  object
# geo_type_name                                         object
# borough                                               object
# geography                                             object
# geography_id                                          object
# ed_annual_adult_estimated_age_adjusted_rate_per10k    object
# ed_annual_adult_rate_per10k                           object
# ed_annual_adult_number                                object
# dtype: object

# %%
#changing to correct datatype
asthma_C_df.year = asthma_C_df.year.astype('category')
asthma_C_df.geo_type_name = asthma_C_df.geo_type_name.astype('category')
asthma_C_df.borough = asthma_C_df.borough.astype('category')
asthma_C_df.geography = asthma_C_df.geography.astype('category')
asthma_C_df.geography_id = asthma_C_df.geography_id.astype('category')

asthma_C_df.ed_annual_adult_estimated_age_adjusted_rate_per10k = asthma_C_df.ed_annual_adult_estimated_age_adjusted_rate_per10k.astype('float')
asthma_C_df.ed_annual_adult_rate_per10k = asthma_C_df.ed_annual_adult_rate_per10k.astype('float')
asthma_C_df.ed_annual_adult_number  = asthma_C_df.ed_annual_adult_number.astype('float')

# %%
asthma_C_df.head(10)
# Out:
#    year geo_type_name        borough       geography geography_id  \
# 0  2005      citywide  new york city   new york city            1
# 1  2006      citywide  new york city   new york city            1
# 2  2007      citywide  new york city   new york city            1
# 3  2008      citywide  new york city   new york city            1
# 4  2009      citywide  new york city   new york city            1
# 5  2010      citywide  new york city   new york city            1
# 6  2011      citywide  new york city   new york city            1
# 7  2012      citywide  new york city   new york city            1
# 8  2013      citywide  new york city   new york city            1
# 9  2014      citywide  new york city   new york city            1
#
#    ed_annual_adult_estimated_age_adjusted_rate_per10k  \
# 0                                               99.5
# 1                                              102.7
# 2                                              104.4
# ...

# %%
#export clean dataset
asthma_C_df.to_csv("C_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_C_df['year'].value_counts()
# Out:
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2016    48
# 2015     1
# Name: year, dtype: int64

# %%
asthma_C_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    462
# borough                   55
# citywide                  12
# Name: geo_type_name, dtype: int64

# %%
asthma_C_uhf42 = asthma_C_df[asthma_C_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_D_df=pd.read_csv('D_Asthma Emergency Department Visits (Children 0 to 4 Yrs Old).csv')

# %%
asthma_D_df.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0              Topic: Health Behavior and Population          NaN
# 1                                   Subtopic: Asthma          NaN
# 2  Indicator Name: Asthma Emergency Department Vi...          NaN
# 3                            Indicator Description:           NaN
# 4                                                NaN          NaN
# 5                                               Year  GeoTypeName
# 6                                               2005     Citywide
# 7                                               2006     Citywide
# 8                                               2007     Citywide
# 9                                               2008     Citywide
#
#       Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# ...

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_D_df = asthma_D_df.drop([0,1,2,3,4])

# %%
 #show that columns 8-9 don't have numerical values
asthma_D_df["Unnamed: 8"].drop_duplicates()
# Out:
# 5    Notes Estimated Annual Rate
# 6                            NaN
# Name: Unnamed: 8, dtype: object

# %%
 #show that columns 8-9 don't have numerical values
asthma_D_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Number
# 6             NaN
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 8-9 because its a notes section with NA values
asthma_D_df = asthma_D_df.drop(columns = ['Unnamed: 9','Unnamed: 8'])

# %%
#rename columns
asthma_D_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_0_4_rate_per10k', 'ed_annual_0_4_number']

# %%
asthma_D_df.head(10)
# Out:
#     year geo_type_name        borough       geography  geography_id  \
# 5   Year   GeoTypeName        Borough       Geography  Geography ID
# 6   2005      Citywide  New York City   New York City             1
# 7   2006      Citywide  New York City   New York City             1
# 8   2007      Citywide  New York City   New York City             1
# 9   2008      Citywide  New York City   New York City             1
# 10  2009      Citywide  New York City   New York City             1
# 11  2010      Citywide  New York City   New York City             1
# 12  2011      Citywide  New York City   New York City             1
# 13  2012      Citywide  New York City   New York City             1
# 14  2013      Citywide  New York City   New York City             1
#
#                                        indicator_name  \
# 5                                      Indicator Name
# 6   Asthma Emergency Department Visits (Children 0...
# ...

# %%
asthma_D_df = asthma_D_df.drop(columns = ['indicator_name'])

# %%
asthma_D_df = asthma_D_df.drop([5])

# %%
asthma_D_df=asthma_D_df.reset_index(drop=True)

# %%
asthma_D_df.tail(30)
# Out:
#                                                   year  \
# 564                                               2005
# 565                                               2006
# 566                                               2007
# 567                                               2008
# 568                                               2009
# 569                                               2010
# 570                                               2011
# 571                                               2012
# 572                                               2013
# 573                                               2014
# 574                                               2015
# 575                                               2016
# 576                                                NaN
# 577  Name:Asthma Emergency Department Visits (Child...
# 578                                      <p>&nbsp;</p>
# 579  <p>ED visits include both patients who are tre...
# ...

# %%
#remove rows 576-593 because they have no contribution to dataset
asthma_D_df = asthma_D_df.drop([576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593])

# %%
asthma_D_df["geo_type_name"]=  asthma_D_df["geo_type_name"].str.lower() 
asthma_D_df["borough"]=  asthma_D_df["borough"].str.lower() 
asthma_D_df["geography"]=  asthma_D_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_D_df = asthma_D_df.replace(',','', regex=True)

# %%
asthma_D_df.dtypes
# Out:
# year                         object
# geo_type_name                object
# borough                      object
# geography                    object
# geography_id                 object
# ed_annual_0_4_rate_per10k    object
# ed_annual_0_4_number         object
# dtype: object

# %%
#changing to correct datatype
asthma_D_df.year = asthma_D_df.year.astype('category')
asthma_D_df.geo_type_name = asthma_D_df.geo_type_name.astype('category')
asthma_D_df.borough = asthma_D_df.borough.astype('category')
asthma_D_df.geography = asthma_D_df.geography.astype('category')
asthma_D_df.geography_id = asthma_D_df.geography_id.astype('category')

asthma_D_df.ed_annual_0_4_rate_per10k = asthma_D_df.ed_annual_0_4_rate_per10k.astype('float')
asthma_D_df.ed_annual_0_4_number   = asthma_D_df.ed_annual_0_4_number .astype('float')

# %%
#export clean dataset
asthma_D_df.to_csv("D_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_D_df['year'].value_counts()
# Out:
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2015    48
# 2016    48
# Name: year, dtype: int64

# %%
asthma_D_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    504
# borough                   60
# citywide                  12
# Name: geo_type_name, dtype: int64

# %%
asthma_D_uhf42 = asthma_D_df[asthma_D_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
asthma_E_df=pd.read_csv('E_Asthma Emergency Department Visits (Children 5 to 17 Yrs Old) by NTA.csv')

# %%
asthma_E_df.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0              Topic: Health Behavior and Population          NaN
# 1                                   Subtopic: Asthma          NaN
# 2  Indicator Name: Asthma Emergency Department Vi...          NaN
# 3                            Indicator Description:           NaN
# 4  Notes: *Estimate is based on small numbers so ...          NaN
# 5                                                NaN          NaN
# 6                                               Year  GeoTypeName
# 7                                          2014-2016     Citywide
# 8                                          2014-2016      Borough
# 9                                          2014-2016      Borough
#
#       Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# ...

# %%
#remove first 5 rows because it has no contribution to dataset
asthma_E_df = asthma_E_df.drop([0,1,2,3,4,5])

# %%
 #show that columns 8-9 don't have numerical values
asthma_E_df["Unnamed: 8"].drop_duplicates()
# Out:
# 6                            Notes Average Annual Number
# 7                                                    NaN
# 359    < 4Estimate is based on small numbers so shoul...
# Name: Unnamed: 8, dtype: object

# %%
 #show that columns 8-9 don't have numerical values
asthma_E_df["Unnamed: 9"].drop_duplicates()
# Out:
# 6                              Notes Average Annual Rate
# 7                                                    NaN
# 359    *Estimate is based on small numbers so should ...
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 8-9 because its a notes section with NA values
asthma_E_df = asthma_E_df.drop(columns = ['Unnamed: 9','Unnamed: 8'])

# %%
#rename columns
asthma_E_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_5_17_nta_number','ed_annual_5_17_nta_rate_per10k']

# %%
asthma_E_df.head(10)
# Out:
#          year       geo_type_name        borough  \
# 6        Year         GeoTypeName        Borough
# 7   2014-2016            Citywide  New York City
# 8   2014-2016             Borough          Bronx
# 9   2014-2016             Borough       Brooklyn
# 10  2014-2016             Borough      Manhattan
# 11  2014-2016             Borough         Queens
# 12  2014-2016             Borough  Staten Island
# 13  2014-2016  Neighborhood (NTA)          Bronx
# 14  2017-2019  Neighborhood (NTA)          Bronx
# 15  2014-2016  Neighborhood (NTA)  Staten Island
#
#                                       geography  geography_id  \
# 6                                     Geography  Geography ID
# 7                                 New York City             1
# 8                                         Bronx             1
# 9                                      Brooklyn             2
# 10                                    Manhattan             3
# ...

# %%
asthma_E_df = asthma_E_df.drop(columns = ['indicator_name'])

# %%
 asthma_E_df = asthma_E_df.drop([6])

# %%
asthma_E_df=asthma_E_df.reset_index(drop=True)

# %%
asthma_E_df.tail(30)
# Out:
#                                                   year  \
# 370                                          2014-2016
# 371                                          2017-2019
# 372                                          2014-2016
# 373                                          2017-2019
# 374                                          2014-2016
# 375                                          2017-2019
# 376                                          2014-2016
# 377                                          2017-2019
# 378                                          2014-2016
# 379                                          2017-2019
# 380                                          2014-2016
# 381                                          2017-2019
# 382                                                NaN
# 383  Name:Asthma Emergency Department Visits (Child...
# 384                                      <p>&nbsp;</p>
# 385  <p>ED visits include both patients who are tre...
# ...

# %%
#remove rows 382-399 because they have no contribution to dataset
asthma_E_df = asthma_E_df.drop([382,383,384,385,386,387,388,389,390,391,392,393,394,395,396,397,398,399])

# %%
asthma_E_df["geo_type_name"]=  asthma_E_df["geo_type_name"].str.lower() 
asthma_E_df["borough"]=  asthma_E_df["borough"].str.lower() 
asthma_E_df["geography"]=  asthma_E_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_E_df = asthma_E_df.replace(',','', regex=True)

# %%
asthma_E_df.dtypes
# Out:
# year                              object
# geo_type_name                     object
# borough                           object
# geography                         object
# geography_id                      object
# ed_annual_5_17_nta_number         object
# ed_annual_5_17_nta_rate_per10k    object
# dtype: object

# %%
#changing to correct datatype
asthma_E_df.year = asthma_E_df.year.astype('category')
asthma_E_df.geo_type_name = asthma_E_df.geo_type_name.astype('category')
asthma_E_df.borough = asthma_E_df.borough.astype('category')
asthma_E_df.geography = asthma_E_df.geography.astype('category')
asthma_E_df.geography_id = asthma_E_df.geography_id.astype('category')

asthma_E_df.ed_annual_5_17_nta_number = asthma_E_df.ed_annual_5_17_nta_number.astype('float')
asthma_E_df.ed_annual_5_17_nta_rate_per10k = asthma_E_df.ed_annual_5_17_nta_rate_per10k.astype('float')

# %%
#export clean dataset
asthma_E_df.to_csv("E_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_E_df['year'].value_counts()
# Out:
# 2014-2016    194
# 2017-2019    188
# Name: year, dtype: int64

# %%
asthma_E_df['geo_type_name'].value_counts()
# Out:
# neighborhood (nta)    376
# borough                 5
# citywide                1
# Name: geo_type_name, dtype: int64

# %%
asthma_F_df=pd.read_csv('F_Asthma Emergency Department Visits (Children 5 to 17 Yrs Old).csv')

# %%
asthma_F_df.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0              Topic: Health Behavior and Population          NaN
# 1                                   Subtopic: Asthma          NaN
# 2  Indicator Name: Asthma Emergency Department Vi...          NaN
# 3  Indicator Description: Severe asthma attacks c...          NaN
# 4                                                NaN          NaN
# 5                                               Year  GeoTypeName
# 6                                               2005     Citywide
# 7                                               2006     Citywide
# 8                                               2007     Citywide
# 9                                               2008     Citywide
#
#       Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 0            NaN             NaN           NaN
# 1            NaN             NaN           NaN
# 2            NaN             NaN           NaN
# ...

# %%
#remove first 4 rows because it has no contribution to dataset
asthma_F_df = asthma_F_df.drop([0,1,2,3,4])

# %%
 #show that columns 8-9 don't have numerical values
asthma_F_df["Unnamed: 8"].drop_duplicates()
# Out:
# 5    Notes Estimated Annual Rate
# 6                            NaN
# Name: Unnamed: 8, dtype: object

# %%
 #show that columns 8-9 don't have numerical values
asthma_F_df["Unnamed: 9"].drop_duplicates()
# Out:
# 5    Notes Number
# 6             NaN
# Name: Unnamed: 9, dtype: object

# %%
#remove columns 8-9 because its a notes section with NA values
asthma_F_df = asthma_F_df.drop(columns = ['Unnamed: 9','Unnamed: 8'])

# %%
asthma_F_df.head(10)
# Out:
#    Unnamed: 0   Unnamed: 1     Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 5        Year  GeoTypeName        Borough       Geography  Geography ID
# 6        2005     Citywide  New York City   New York City             1
# 7        2006     Citywide  New York City   New York City             1
# 8        2007     Citywide  New York City   New York City             1
# 9        2008     Citywide  New York City   New York City             1
# 10       2009     Citywide  New York City   New York City             1
# 11       2010     Citywide  New York City   New York City             1
# 12       2011     Citywide  New York City   New York City             1
# 13       2012     Citywide  New York City   New York City             1
# 14       2013     Citywide  New York City   New York City             1
#
#    Asthma Emergency Department Visits (Children 5 to 17 Yrs Old) : Summarize  \
# 5                                      Indicator Name
# ...

# %%
#rename columns
asthma_F_df.columns=['year','geo_type_name','borough','geography','geography_id','indicator_name','ed_annual_5_17_rate_per10k', 'ed_annual_5_17_number']

# %%
 asthma_F_df = asthma_F_df.drop([5])

# %%
asthma_F_df=asthma_F_df.reset_index(drop=True)

# %%
asthma_F_df = asthma_F_df.drop(columns = ['indicator_name'])

# %%
asthma_F_df.tail(30)
# Out:
#                                                   year  \
# 564                                               2005
# 565                                               2006
# 566                                               2007
# 567                                               2008
# 568                                               2009
# 569                                               2010
# 570                                               2011
# 571                                               2012
# 572                                               2013
# 573                                               2014
# 574                                               2015
# 575                                               2016
# 576                                                NaN
# 577  Name:Asthma Emergency Department Visits (Child...
# 578                                      <p>&nbsp;</p>
# 579  <p>ED visits include both patients who are tre...
# ...

# %%
#remove rows 576-599 because they have no contribution to dataset
asthma_F_df = asthma_F_df.drop([576,577,578,579,580,581,582,583,584,585,586,587,588,589,590,591,592,593])

# %%
asthma_F_df["geo_type_name"]=  asthma_F_df["geo_type_name"].str.lower() 
asthma_F_df["borough"]=  asthma_F_df["borough"].str.lower() 
asthma_F_df["geography"]=  asthma_F_df["geography"].str.lower()

# %%
#remove commas from all values 
asthma_F_df = asthma_F_df.replace(',','', regex=True)

# %%
asthma_F_df.dtypes
# Out:
# year                          object
# geo_type_name                 object
# borough                       object
# geography                     object
# geography_id                  object
# ed_annual_5_17_rate_per10k    object
# ed_annual_5_17_number         object
# dtype: object

# %%
#changing to correct datatype
asthma_F_df.year = asthma_F_df.year.astype('category')
asthma_F_df.geo_type_name = asthma_F_df.geo_type_name.astype('category')
asthma_F_df.borough = asthma_F_df.borough.astype('category')
asthma_F_df.geography = asthma_F_df.geography.astype('category')
asthma_F_df.geography_id = asthma_F_df.geography_id.astype('category')

asthma_F_df.ed_annual_5_17_number = asthma_F_df.ed_annual_5_17_number.astype('float')
asthma_F_df.ed_annual_5_17_rate_per10k = asthma_F_df.ed_annual_5_17_rate_per10k.astype('float')

# %%
#export clean dataset
asthma_F_df.to_csv("F_clean.csv", encoding="utf-8")

# %%
########## MERGING
asthma_F_df['year'].value_counts()
# Out:
# 2005    48
# 2006    48
# 2007    48
# 2008    48
# 2009    48
# 2010    48
# 2011    48
# 2012    48
# 2013    48
# 2014    48
# 2015    48
# 2016    48
# Name: year, dtype: int64

# %%
asthma_F_df['geo_type_name'].value_counts()
# Out:
# neighborhood (uhf 42)    504
# borough                   60
# citywide                  12
# Name: geo_type_name, dtype: int64

# %%
asthma_F_uhf42 = asthma_F_df[asthma_F_df.geo_type_name == 'neighborhood (uhf 42)']

# %%
### MERGE DATASETS C,D,F
asthma_C_D_uhf42 = asthma_C_uhf42.merge(asthma_D_uhf42, on = ['geography_id'])
asthma_C_D_F_uhf42 = asthma_C_D_uhf42.merge(asthma_F_uhf42, on = ['geography_id'])
asthma_C_D_F_uhf42.head()
# Out:
#   year_x        geo_type_name_x borough_x             geography_x  \
# 0   2005  neighborhood (uhf 42)    queens   bayside - little neck
# 1   2005  neighborhood (uhf 42)    queens   bayside - little neck
# 2   2005  neighborhood (uhf 42)    queens   bayside - little neck
# 3   2005  neighborhood (uhf 42)    queens   bayside - little neck
# 4   2005  neighborhood (uhf 42)    queens   bayside - little neck
#
#   geography_id  ed_annual_adult_estimated_age_adjusted_rate_per10k  \
# 0          404                                               16.3
# 1          404                                               16.3
# 2          404                                               16.3
# 3          404                                               16.3
# 4          404                                               16.3
#
#    ed_annual_adult_rate_per10k  ed_annual_adult_number year_y  \
# 0                         15.2                   106.0   2005
# ...

# %%
asthma_C_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_C_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_C_uhf42['borough'].value_counts()
# Out:
# brooklyn         121
# manhattan        110
# queens           110
# bronx             77
# staten island     44
# new york city      0
# Name: borough, dtype: int64

# %%
asthma_D_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_D_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_D_uhf42['borough'].value_counts()
# Out:
# brooklyn         132
# manhattan        120
# queens           120
# bronx             84
# staten island     48
# new york city      0
# Name: borough, dtype: int64

# %%
asthma_F_uhf42['geography'].value_counts().shape
# Out:
# (48,)

# %%
asthma_F_uhf42['geography_id'].value_counts().shape
# Out:
# (47,)

# %%
asthma_F_uhf42['borough'].value_counts()
# Out:
# brooklyn         132
# manhattan        120
# queens           120
# bronx             84
# staten island     48
# new york city      0
# Name: borough, dtype: int64

# %%
# geography_id, geography and borough columns correspond as they should so will now also merge those columns too

### MERGE DATASETS M,O,Q by year, geo ID, geography and borough

asthma_C_D_uhf42 = asthma_C_uhf42.merge(asthma_D_uhf42, on = ['year','borough','geography_id',"geography","geo_type_name"])
asthma_C_D_F_uhf42 = asthma_C_D_uhf42.merge(asthma_F_uhf42, on = ['year','borough','geography_id',"geography", "geo_type_name"])
asthma_C_D_F_uhf42.head()
# Out:
#    year          geo_type_name borough               geography geography_id  \
# 0  2005  neighborhood (uhf 42)  queens   bayside - little neck          404
# 1  2006  neighborhood (uhf 42)  queens   bayside - little neck          404
# 2  2007  neighborhood (uhf 42)  queens   bayside - little neck          404
# 3  2008  neighborhood (uhf 42)  queens   bayside - little neck          404
# 4  2009  neighborhood (uhf 42)  queens   bayside - little neck          404
#
#    ed_annual_adult_estimated_age_adjusted_rate_per10k  \
# 0                                               16.3
# 1                                               17.4
# 2                                               18.7
# 3                                               17.1
# 4                                               23.2
#
#    ed_annual_adult_rate_per10k  ed_annual_adult_number  \
# 0                         15.2                   106.0
# 1                         17.9                   125.0
# ...

# %%
asthma_C_D_F_uhf42.dtypes
# Out:
# year                                                  category
# geo_type_name                                         category
# borough                                               category
# geography                                             category
# geography_id                                          category
# ed_annual_adult_estimated_age_adjusted_rate_per10k     float64
# ed_annual_adult_rate_per10k                            float64
# ed_annual_adult_number                                 float64
# ed_annual_0_4_rate_per10k                              float64
# ed_annual_0_4_number                                   float64
# ed_annual_5_17_rate_per10k                             float64
# ed_annual_5_17_number                                  float64
# dtype: object

# %%
#export merged uhf42 for emergency department data
asthma_C_D_F_uhf42.to_csv("MERGED_asthmaCDF_ED_uhf42.csv", encoding="utf-8")
